# %%
#@title Global Settings
from tensorflow import keras
import tensorflow.keras.layers
import tensorflow.keras.models
import tensorflow.keras.datasets
from tensorflow.keras import regularizers

# %%
dataset=tensorflow.keras.datasets.cifar100 #@param ["tensorflow.keras.datasets.cifar10", "tensorflow.keras.datasets.cifar100", "tensorflow.keras.datasets.mnist", "tensorflow.keras.datasets.fashion_mnist"] {type:"raw"} 
batch_size=64 # @param [32, 64, 128, 256, 512] {type:"raw"} 
epochs=32 # @param [32, 64, 128, 256, 512] {type:"raw"}
l2_decay = 0.000001 #@param {type:"number"}
initial_learning_rate = 0.01 #@param {type:"number"}
verbose=True #@param {type:"boolean"}
bipolar_input=True #@param {type:"boolean"}

if dataset is keras.datasets.cifar10 or dataset is keras.datasets.cifar100:
  input_shape = (32, 32, 3)
else:
  input_shape = (28, 28, 1)

# %%
import os
import cai.densenet
import cai.util

save_dir = os.path.join(os.getcwd(), 'saved_models')
cai.util.create_folder_if_required(save_dir)
base_model_name = os.path.join(save_dir, 'simple_model_on_any_dataset')

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(64, (5, 5), padding='valid',
                 input_shape=input_shape, kernel_regularizer=regularizers.l2(l2_decay)) )
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(4, 4)))
model.add(keras.layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=regularizers.l2(l2_decay)) )
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=regularizers.l2(l2_decay)) )
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(32, kernel_regularizer=regularizers.l2(l2_decay)) )
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dense(32, kernel_regularizer=regularizers.l2(l2_decay)) )
model.add(keras.layers.Activation('relu'))
if (dataset==keras.datasets.cifar100):
  model.add(keras.layers.Dense(100))
else:
  model.add(keras.layers.Dense(10))
model.add(keras.layers.Activation('softmax'))

if (verbose):
    model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 28, 28, 64)        4864
#
#  activation_12 (Activation)  (None, 28, 28, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_13 (Activation)  (None, 7, 7, 64)          0
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_14 (Activation)  (None, 7, 7, 64)          0
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_5 (Dense)             (None, 32)                100384
#
#  activation_15 (Activation)  (None, 32)                0
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  activation_16 (Activation)  (None, 32)                0
#
#  dense_7 (Dense)             (None, 100)               3300
#
#  activation_17 (Activation)  (None, 100)               0
#
# =================================================================
# Total params: 183460 (716.64 KB)
# Trainable params: 183460 (716.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Learning rate schedule.
def lrscheduler(epoch):
    return initial_learning_rate * (0.99**epoch)

fit_result, model_name, csv_name = cai.datasets.train_model_on_dataset(model,
                                                                       dataset,
                                                                       base_model_name,
                                                                       plrscheduler=lrscheduler,
                                                                       batch_size=batch_size,
                                                                       epochs=epochs,
                                                                       lab=False,
                                                                       verbose=verbose,
                                                                       bipolar=bipolar_input)
# Out:
# train shape (50000, 32, 32, 3)
# test shape (10000, 32, 32, 3)
# Original channel  0  min: 0.0  max: 255.0
# Original channel  1  min: 0.0  max: 255.0
# Original channel  2  min: 0.0  max: 255.0
# Loading RGB.
# Channel  0  min: -2.0  max: 1.984375
# Channel  1  min: -2.0  max: 1.984375
# Channel  2  min: -2.0  max: 1.984375
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/32
#
# Epoch 1: val_accuracy improved from -inf to 0.11358, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# /home/hamid/.local/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 781/781 - 49s - loss: 4.2160 - accuracy: 0.0560 - val_loss: 3.7857 - val_accuracy: 0.1136 - lr: 0.0100 - 49s/epoch - 62ms/step
# Epoch 2/32
#
# Epoch 2: val_accuracy improved from 0.11358 to 0.17588, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 44s - loss: 3.6393 - accuracy: 0.1318 - val_loss: 3.3748 - val_accuracy: 0.1759 - lr: 0.0099 - 44s/epoch - 56ms/step
# Epoch 3/32
#
# Epoch 3: val_accuracy improved from 0.17588 to 0.21795, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 42s - loss: 3.3745 - accuracy: 0.1807 - val_loss: 3.1666 - val_accuracy: 0.2179 - lr: 0.0098 - 42s/epoch - 53ms/step
# Epoch 4/32
#
# Epoch 4: val_accuracy improved from 0.21795 to 0.24179, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 48s - loss: 3.1984 - accuracy: 0.2133 - val_loss: 3.0561 - val_accuracy: 0.2418 - lr: 0.0097 - 48s/epoch - 61ms/step
# Epoch 5/32
#
# Epoch 5: val_accuracy improved from 0.24179 to 0.27925, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 48s - loss: 3.0567 - accuracy: 0.2392 - val_loss: 2.8852 - val_accuracy: 0.2792 - lr: 0.0096 - 48s/epoch - 61ms/step
# Epoch 6/32
#
# Epoch 6: val_accuracy improved from 0.27925 to 0.28195, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 47s - loss: 2.9392 - accuracy: 0.2612 - val_loss: 2.8567 - val_accuracy: 0.2820 - lr: 0.0095 - 47s/epoch - 61ms/step
# Epoch 7/32
#
# Epoch 7: val_accuracy improved from 0.28195 to 0.30759, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 44s - loss: 2.8531 - accuracy: 0.2762 - val_loss: 2.7404 - val_accuracy: 0.3076 - lr: 0.0094 - 44s/epoch - 56ms/step
# Epoch 8/32
#
# Epoch 8: val_accuracy improved from 0.30759 to 0.31591, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 49s - loss: 2.7851 - accuracy: 0.2896 - val_loss: 2.6495 - val_accuracy: 0.3159 - lr: 0.0093 - 49s/epoch - 63ms/step
# Epoch 9/32
#
# Epoch 9: val_accuracy improved from 0.31591 to 0.33423, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 46s - loss: 2.7170 - accuracy: 0.3051 - val_loss: 2.6251 - val_accuracy: 0.3342 - lr: 0.0092 - 46s/epoch - 59ms/step
# Epoch 10/32
#
# Epoch 10: val_accuracy did not improve from 0.33423
# 781/781 - 46s - loss: 2.6718 - accuracy: 0.3142 - val_loss: 2.6002 - val_accuracy: 0.3295 - lr: 0.0091 - 46s/epoch - 59ms/step
# Epoch 11/32
#
# Epoch 11: val_accuracy improved from 0.33423 to 0.35076, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 46s - loss: 2.6355 - accuracy: 0.3226 - val_loss: 2.5276 - val_accuracy: 0.3508 - lr: 0.0090 - 46s/epoch - 59ms/step
# Epoch 12/32
#
# Epoch 12: val_accuracy improved from 0.35076 to 0.35196, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 51s - loss: 2.5849 - accuracy: 0.3331 - val_loss: 2.4972 - val_accuracy: 0.3520 - lr: 0.0090 - 51s/epoch - 66ms/step
# Epoch 13/32
#
# Epoch 13: val_accuracy improved from 0.35196 to 0.36689, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 48s - loss: 2.5607 - accuracy: 0.3378 - val_loss: 2.4593 - val_accuracy: 0.3669 - lr: 0.0089 - 48s/epoch - 61ms/step
# Epoch 14/32
#
# Epoch 14: val_accuracy did not improve from 0.36689
# 781/781 - 47s - loss: 2.5246 - accuracy: 0.3464 - val_loss: 2.5720 - val_accuracy: 0.3543 - lr: 0.0088 - 47s/epoch - 60ms/step
# Epoch 15/32
#
# Epoch 15: val_accuracy did not improve from 0.36689
# 781/781 - 47s - loss: 2.5018 - accuracy: 0.3517 - val_loss: 2.5247 - val_accuracy: 0.3543 - lr: 0.0087 - 47s/epoch - 60ms/step
# Epoch 16/32
#
# Epoch 16: val_accuracy improved from 0.36689 to 0.38271, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 47s - loss: 2.4667 - accuracy: 0.3583 - val_loss: 2.3869 - val_accuracy: 0.3827 - lr: 0.0086 - 47s/epoch - 60ms/step
# Epoch 17/32
#
# Epoch 17: val_accuracy improved from 0.38271 to 0.38842, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 48s - loss: 2.4448 - accuracy: 0.3641 - val_loss: 2.3651 - val_accuracy: 0.3884 - lr: 0.0085 - 48s/epoch - 62ms/step
# Epoch 18/32
#
# Epoch 18: val_accuracy did not improve from 0.38842
# 781/781 - 47s - loss: 2.4292 - accuracy: 0.3657 - val_loss: 2.4592 - val_accuracy: 0.3722 - lr: 0.0084 - 47s/epoch - 60ms/step
# Epoch 19/32
#
# Epoch 19: val_accuracy improved from 0.38842 to 0.39223, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 47s - loss: 2.4081 - accuracy: 0.3700 - val_loss: 2.3834 - val_accuracy: 0.3922 - lr: 0.0083 - 47s/epoch - 60ms/step
# Epoch 20/32
#
# Epoch 20: val_accuracy improved from 0.39223 to 0.40505, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 48s - loss: 2.3823 - accuracy: 0.3764 - val_loss: 2.3225 - val_accuracy: 0.4050 - lr: 0.0083 - 48s/epoch - 61ms/step
# Epoch 21/32
#
# Epoch 21: val_accuracy did not improve from 0.40505
# 781/781 - 47s - loss: 2.3550 - accuracy: 0.3779 - val_loss: 2.3584 - val_accuracy: 0.3875 - lr: 0.0082 - 47s/epoch - 60ms/step
# Epoch 22/32
#
# Epoch 22: val_accuracy improved from 0.40505 to 0.40825, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 47s - loss: 2.3536 - accuracy: 0.3806 - val_loss: 2.2540 - val_accuracy: 0.4083 - lr: 0.0081 - 47s/epoch - 61ms/step
# Epoch 23/32
#
# Epoch 23: val_accuracy improved from 0.40825 to 0.41156, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 49s - loss: 2.3303 - accuracy: 0.3868 - val_loss: 2.2928 - val_accuracy: 0.4116 - lr: 0.0080 - 49s/epoch - 63ms/step
# Epoch 24/32
#
# Epoch 24: val_accuracy did not improve from 0.41156
# 781/781 - 46s - loss: 2.3166 - accuracy: 0.3896 - val_loss: 2.2753 - val_accuracy: 0.3999 - lr: 0.0079 - 46s/epoch - 59ms/step
# Epoch 25/32
#
# Epoch 25: val_accuracy did not improve from 0.41156
# 781/781 - 46s - loss: 2.3052 - accuracy: 0.3928 - val_loss: 2.3050 - val_accuracy: 0.4013 - lr: 0.0079 - 46s/epoch - 58ms/step
# Epoch 26/32
#
# Epoch 26: val_accuracy did not improve from 0.41156
# 781/781 - 43s - loss: 2.2890 - accuracy: 0.3943 - val_loss: 2.3321 - val_accuracy: 0.3975 - lr: 0.0078 - 43s/epoch - 55ms/step
# Epoch 27/32
#
# Epoch 27: val_accuracy did not improve from 0.41156
# 781/781 - 37s - loss: 2.2749 - accuracy: 0.4010 - val_loss: 2.3169 - val_accuracy: 0.3967 - lr: 0.0077 - 37s/epoch - 48ms/step
# Epoch 28/32
#
# Epoch 28: val_accuracy improved from 0.41156 to 0.42748, saving model to /home/hamid/M.Eng. Project/k-neural-examples/saved_models/simple_model_on_any_dataset.h5
# 781/781 - 37s - loss: 2.2603 - accuracy: 0.4026 - val_loss: 2.1883 - val_accuracy: 0.4275 - lr: 0.0076 - 37s/epoch - 47ms/step
# Epoch 29/32
#
# Epoch 29: val_accuracy did not improve from 0.42748
# 781/781 - 38s - loss: 2.2530 - accuracy: 0.4034 - val_loss: 2.2703 - val_accuracy: 0.4104 - lr: 0.0075 - 38s/epoch - 48ms/step
# Epoch 30/32
#
# Epoch 30: val_accuracy did not improve from 0.42748
# 781/781 - 39s - loss: 2.2387 - accuracy: 0.4089 - val_loss: 2.2761 - val_accuracy: 0.4179 - lr: 0.0075 - 39s/epoch - 50ms/step
# Epoch 31/32
#
# Epoch 31: val_accuracy did not improve from 0.42748
# 781/781 - 39s - loss: 2.2153 - accuracy: 0.4117 - val_loss: 2.3277 - val_accuracy: 0.4142 - lr: 0.0074 - 39s/epoch - 50ms/step
# Epoch 32/32
#
# Epoch 32: val_accuracy did not improve from 0.42748
# 781/781 - 38s - loss: 2.2136 - accuracy: 0.4144 - val_loss: 2.2243 - val_accuracy: 0.4207 - lr: 0.0073 - 38s/epoch - 49ms/step
