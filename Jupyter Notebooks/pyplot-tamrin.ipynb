# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(0,3* np.pi , 0.1)
y1 = np.sin(x)
plt.plot(x,y1)

# %%
y2 = np.cos(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')
